# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

from singlestock import explorebuysell        
        
explorebuysell(symbol='GOOG').bollinger(ftype='alternate')
explorebuysell(symbol='GOOG').bollinger(ftype='no')
explorebuysell(symbol='YHOO').dualcrossover(ftype='alternate')
explorebuysell(symbol='AMZN').channeltrading(ftype='alternate')
# Out:
# GOOG - data found locally
# GOOG - data found locally
# YHOO - data found locally
# AMZN - data found locally
