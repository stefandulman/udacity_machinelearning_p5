# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import pandas as pd
import numpy as np
import seaborn

from visualizedata import retrievedata

symbols = [
  'AAPL', 
  'AMZN', 
  'GOOG', 
  'MSFT', 
  'YHOO',
  'SPY'
]

# testing retrievedata
for s in symbols:
    retrievedata(s)
# Out:
# AAPL - data found locally
# AMZN - data found locally
# GOOG - data found locally
# MSFT - data found locally
# YHOO - data found locally
# SPY - data found locally

# %%
from visualizedata import visualize
  
visualize(symbols, scaled=False, title="Time evolution of adj_close value of stocks")
visualize(symbols, scaled=True, title="Time evolution of normalized adj_close value of stocks")

# %%
from visualizedata import printstats
        
printstats(symbols)
# Out:
#                  AAPL         AMZN         GOOG         MSFT         YHOO  \
# count     1510.000000  1510.000000  1510.000000  1510.000000  1510.000000
# mean        81.900311   371.069378   492.603993    36.033561    29.245126
# std         24.818785   184.300263   166.979628    11.658178    11.176455
# min         40.852719   160.970001   237.203209    20.235039    11.090000
# 25%         59.541841   227.832493   317.359435    25.529201    16.352500
# 50%         78.772208   310.039994   518.337372    34.095152    32.135001
# 75%        105.045151   439.922508   601.171133    44.732755    38.317500
# max        127.966091   844.359985   813.109985    63.236627    52.369999
# kurtosis    -1.241766    -0.110700    -1.203827    -1.026480    -1.379185
#
#                   SPY
# count     1510.000000
# mean       162.839163
# std         36.402117
# min         98.124049
# 25%        125.596334
# 50%        168.687705
# 75%        197.495022
# max        225.444643
# ...
